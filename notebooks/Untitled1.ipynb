# %%
import pandas as pd
from glob import glob

# %%
images = sorted(glob("../data/processed/train/images/*.jpg"))
masks = sorted(glob("../data/processed/train/masks/*.jpg"))

# %%
images = [f"{i}.jpg" for i in range(997)]

# %%
dataframe = pd.DataFrame(data = {"Images" : images, "Masks" : images})

# %%
dataframe.head()
# Out:
#   Images  Masks
# 0  0.jpg  0.jpg
# 1  1.jpg  1.jpg
# 2  2.jpg  2.jpg
# 3  3.jpg  3.jpg
# 4  4.jpg  4.jpg

# %%
from PIL import Image

# %%
Image.open("../data/processed/train/images/1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
Image.open("../data/processed/train/masks/1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>
